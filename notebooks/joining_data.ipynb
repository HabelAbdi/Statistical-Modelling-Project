# %%
import pandas as pd

yelpcombined1_df.rename(columns={'coordinates.latitude': 'latitude'}, inplace=True)
yelpcombined1_df.rename(columns={'coordinates.longitude': 'longitude'}, inplace=True)
# yelpcombined1_df

# %% [markdown]
# Join the data from Part 1 with the data from Part 2 to create a new dataframe.

# %%
import pandas as pd

# merged_df2.to_csv('/Users/habeelabdi/Desktop/LL/LL 2/merged_df2.csv', index=False)
merged_df2 = pd.read_csv('/Users/habeelabdi/Desktop/LL/LL 2/merged_df2.csv')

display((merged_df2).head(1))
# Out:
#                    id_df1                      alias           name_df1  \
# 0  kktb-uIc2YjNWOdbW4ktCg  delina-restaurant-toronto  Delina Restaurant
#
#                                            image_url  is_closed  \
# 0  https://s3-media4.fl.yelpcdn.com/bphoto/U66lN3...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/delina-restaurant-tor...            56
#
#                                           categories  rating transactions  \
# 0  [{'alias': 'mideastern', 'title': 'Middle East...     4.5           []
#
#   price        phone    display_phone     distance  latitude_df1  \
# 0     $  16473482009  +1 647-348-2009  1045.239101      43.66864
#
#    longitude_df1    location.address1  location.address2  location.address3  \
# 0      -79.30517  1891 Queen Street E                NaN                NaN
#
#   location.city location.zip_code location.country location.state  \
# ...

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
# display(merged_df2.head(2))
# merged_df2.columns
# merged_df2.shape
# merged_df2.info
# merged_df2.describe()
# merged_df2

# %% [markdown]
# Provide a visualization that you used as part of your EDA process. Explain the initial pattern or relationship you discoved through this visualization.

# %%
merged_df2.head(10)
# Out:
#                    id_df1                                 alias  \
# 0  kktb-uIc2YjNWOdbW4ktCg             delina-restaurant-toronto
# 1  kktb-uIc2YjNWOdbW4ktCg             delina-restaurant-toronto
# 2  kktb-uIc2YjNWOdbW4ktCg             delina-restaurant-toronto
# 3  uChnTTQzV7Nu7EDrluF6uw            sauvignon-bistro-toronto-2
# 4  uChnTTQzV7Nu7EDrluF6uw            sauvignon-bistro-toronto-2
# 5  uChnTTQzV7Nu7EDrluF6uw            sauvignon-bistro-toronto-2
# 6  gfDi1N1HFhdyKnirFMBaeA         ichiban-sushi-house-toronto-5
# 7  gfDi1N1HFhdyKnirFMBaeA         ichiban-sushi-house-toronto-5
# 8  gfDi1N1HFhdyKnirFMBaeA         ichiban-sushi-house-toronto-5
# 9  WoPiDRfK8m8jODlQMixBlQ  maestro-omar-s-gourmet-pizza-toronto
#
#                        name_df1  \
# 0             Delina Restaurant
# 1             Delina Restaurant
# 2             Delina Restaurant
# 3              Sauvignon Bistro
# 4              Sauvignon Bistro
# 5              Sauvignon Bistro
# ...

# %%
import pandas as pd
# pd.set_option('display.max_columns', None)
# display(merged_df2.head(2))
# merged_df2.columns
# merged_df2.shape
# merged_df2.isnull().sum
# merged_df2.info
# merged_df2.describe()
# merged_df2
# Out:
# Index(['id_df1', 'alias', 'name_df1', 'image_url', 'is_closed', 'url',
#        'review_count', 'categories', 'rating', 'transactions', 'price',
#        'phone', 'display_phone', 'distance', 'latitude_df1', 'longitude_df1',
#        'location.address1', 'location.address2', 'location.address3',
#        'location.city', 'location.zip_code', 'location.country',
#        'location.state', 'location.display_address', 'empty_slots', 'extra',
#        'free_bikes', 'id_bike_stations', 'latitude_bike_stations',
#        'longitude_bike_stations', 'name_bike_stations', 'timestamp'],
#       dtype='object')

# %%
# columns_to_drop = ['location.state', 'extra', 'url', 'image_url', 'transactions', 'phone', 'display_phone', 'location.city', 'is_closed', 'location.country']

# remove the specified columns
# merged_df2 = merged_df2.drop(columns=columns_to_drop)

# print(merged_df2.isnull().sum())
merged_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89 entries, 0 to 88
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id_df1                    89 non-null     object
#  1   alias                     89 non-null     object
#  2   name_df1                  89 non-null     object
#  3   review_count              89 non-null     int64
#  4   categories                89 non-null     object
#  5   rating                    89 non-null     float64
#  6   distance                  89 non-null     float64
#  7   latitude_df1              89 non-null     float64
#  8   longitude_df1             89 non-null     float64
#  9   location.address1         89 non-null     object
#  10  location.zip_code         89 non-null     object
#  11  location.display_address  89 non-null     object
#  12  empty_slots               89 non-null     int64
# ...

# %%
merged_df2.describe()
# Out:
#        review_count     rating     distance  latitude_df1  longitude_df1  \
# count     89.000000  89.000000    89.000000     89.000000      89.000000
# mean      48.337079   3.780899   926.464597     43.666944     -79.312871
# std      103.444314   0.825568   191.790516      0.001765       0.005669
# min        1.000000   1.500000   291.415216     43.662741     -79.321320
# 25%        7.000000   3.500000   882.344385     43.666270     -79.316930
# 50%       19.000000   4.000000   964.389447     43.666816     -79.315585
# 75%       56.000000   4.500000  1070.680179     43.668640     -79.307099
# max      510.000000   5.000000  1121.173921     43.669060     -79.304150
#
#        empty_slots  free_bikes  latitude_bike_stations  \
# count    89.000000   89.000000               89.000000
# mean      7.404494   12.483146               43.668012
# std       3.913029    3.230228                0.003225
# min       2.000000    4.000000               43.660206
# ...

# %% [markdown]
# Review Count (review_count):
#
# - Mean (Average): Approximately 48.34 reviews.
# - High variability, indicated by a standard deviation of approximately 103.44.
# - Data is right-skewed, as the mean is greater than the median (50th percentile).
#
# Rating (rating):
# - Mean (Average): Approximately 3.78.
# - Moderate variability, with a standard deviation of approximately 0.83.
# - The ratings are spread across the scale, with a median (50th percentile) of 4.
#
# Distance (distance):
#
# - Mean (Average): Approximately 926.46 meters.
# - Moderate variability, with a standard deviation of approximately 191.79.
# - he distances are spread out, with a right-skewed distribution.
#
# Empty Slots (empty_slots):
#
# - Mean (Average): Approximately 7.40.
# - Moderate variability, with a standard deviation of approximately 3.91.
# - The number of empty slots has a right-skewed distribution.
#
# Free Bikes (free_bikes):
#
# - Mean (Average): Approximately 12.48.
# - Moderate variability, with a standard deviation of approximately 3.23.
# - The number of free bikes has a right-skewed distribution.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
sns.barplot(x='free_bikes', y='name_bike_stations', data=merged_df2)
plt.title('Average Rating')
plt.show()

plt.figure(figsize=(12, 6))
sns.barplot(x='free_bikes', y='rating', data=merged_df2)
plt.title('Average Rating')
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib import pyplot as plt

plt.hist(merged_df2['rating'])
plt.show()

# %%
import seaborn as sns

# sns.set_theme(palette='colorblind')

# #seaborn histogram
sns.histplot(data=merged_df2, x='rating', y= 'name_bike_stations')

plt.show()

# %%
import seaborn as sns

# sns.set_theme(palette='colorblind')

# #seaborn histogram
sns.histplot(data=merged_df2, x='rating', y= 'name_bike_stations')

plt.show()

# %%
# #seaborn boxplot
sns.boxplot(data=merged_df2, y='rating', whis=1.5, width=0.3)

plt.show()

# %%
#seaborn boxplot
sns.boxplot(data=merged_df2, y='empty_slots', whis=1.5, width=0.3)

plt.show()

# %%
#seaborn boxplot
sns.boxplot(data=merged_df2, y='free_bikes', whis=1.5, width=0.3)

plt.show()

# %%
sns.pairplot(merged_df2[['rating', 'free_bikes', 'empty_slots']])
plt.show()
# Out:
# /Users/habeelabdi/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning:
#
# The figure layout has changed to tight

# %% [markdown]
# # Database

# %%
import sqlite3
import pandas as pd

# Connect to the SQLite database
conn = sqlite3.connect('/Users/habeelabdi/Desktop/LL/LL 2/merged_df.db')

# Execute a query to check for missing values
missing_values_query = "SELECT * FROM merged_df2 WHERE price IS NULL"
missing_values_df = pd.read_sql_query(missing_values_query, conn)

# Execute a query to check for inconsistent values
inconsistent_values_query = "SELECT * FROM merged_df2 WHERE review_count < 0 OR review_count > 100"
inconsistent_values_df = pd.read_sql_query(inconsistent_values_query, conn)

# Close the connection to the SQLite database
conn.close()

# %%
import sqlite3
import pandas as pd

# Connect to the SQLite database
conn = sqlite3.connect('/Users/habeelabdi/Desktop/LL/LL 2/merged_df.db')

# Execute a query to retrieve the table schema
schema_query = "PRAGMA table_info(merged_df2)"
schema_df = pd.read_sql_query(schema_query, conn)
print(schema_df)
# Close the connection to the SQLite database
conn.close()

#A value of 0 for notnull means the column allows NULL values
#A flag indicating if the column is part of the primary key
# Out:
#     cid                     name     type  notnull dflt_value  pk
# 0     0                   id_df1     TEXT        0       None   0
# 1     1                    alias     TEXT        0       None   0
# 2     2                 name_df1     TEXT        0       None   0
# 3     3                image_url     TEXT        0       None   0
# 4     4                is_closed  INTEGER        0       None   0
# 5     5                      url     TEXT        0       None   0
# 6     6             review_count  INTEGER        0       None   0
# 7     7               categories     TEXT        0       None   0
# 8     8                   rating     REAL        0       None   0
# 9     9             transactions     TEXT        0       None   0
# 10   10                    price     TEXT        0       None   0
# 11   11                    phone  INTEGER        0       None   0
# 12   12            display_phone     TEXT        0       None   0
# ...

# %%
import sqlite3
import pandas as pd

# Connect to the SQLite database
conn = sqlite3.connect('/Users/habeelabdi/Desktop/LL/LL 2/merged_df.db')

# Execute a query to retrieve the first few rows of the merged dataset
data_query = "SELECT * FROM merged_df2 LIMIT 5"
data_df = pd.read_sql_query(data_query, conn)
print(data_df)
# Close the connection to the SQLite database
conn.close()
# Out:
#                    id_df1                       alias           name_df1  \
# 0  kktb-uIc2YjNWOdbW4ktCg   delina-restaurant-toronto  Delina Restaurant
# 1  kktb-uIc2YjNWOdbW4ktCg   delina-restaurant-toronto  Delina Restaurant
# 2  kktb-uIc2YjNWOdbW4ktCg   delina-restaurant-toronto  Delina Restaurant
# 3  uChnTTQzV7Nu7EDrluF6uw  sauvignon-bistro-toronto-2   Sauvignon Bistro
# 4  uChnTTQzV7Nu7EDrluF6uw  sauvignon-bistro-toronto-2   Sauvignon Bistro
#
#                                            image_url  is_closed  \
# 0  https://s3-media4.fl.yelpcdn.com/bphoto/U66lN3...          0
# 1  https://s3-media4.fl.yelpcdn.com/bphoto/U66lN3...          0
# 2  https://s3-media4.fl.yelpcdn.com/bphoto/U66lN3...          0
# 3  https://s3-media2.fl.yelpcdn.com/bphoto/MEYYbe...          0
# 4  https://s3-media2.fl.yelpcdn.com/bphoto/MEYYbe...          0
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/delina-restaurant-tor...            56
# ...

# %%
# Check for missing data
missing_data = merged_df2.isnull().sum()
print("Missing Data:")
print(missing_data)

# Check for duplicated data
duplicated_data = merged_df2.duplicated().sum()
print("\nDuplicated Data:")
print(duplicated_data)
# Out:
# Missing Data:
# id_df1                      0
# alias                       0
# name_df1                    0
# review_count                0
# categories                  0
# rating                      0
# distance                    0
# latitude_df1                0
# longitude_df1               0
# location.address1           0
# location.zip_code           0
# location.display_address    0
# empty_slots                 0
# free_bikes                  0
# id_bike_stations            0
# latitude_bike_stations      0
# longitude_bike_stations     0
# name_bike_stations          0
# timestamp                   0
# dtype: int64
#
# Duplicated Data:
# 15

# %% [markdown]
# Put all your results in an SQLite3 database (remember, SQLite stores its databases as files in your local machine - make sure to create your database in your project's data/ directory!)

# %% [markdown]
# Look at the data before and after the join to validate your data.

# %%
import sqlite3
import pandas as pd

file_path = '/Users/habeelabdi/Desktop/LL/LL 2/final_merged_df2.csv'
merged_df2 = pd.read_csv(file_path)

# Rename 'Location' column to 'address'
merged_df2.rename(columns={'Location': 'address'}, inplace=True, errors='ignore')

# Connect to a new SQLite database in your directory
new_conn = sqlite3.connect('/Users/habeelabdi/Desktop/LL/LL 2/merged_df.db')

# Save the DataFrame to the SQLite database
with new_conn:
    merged_df2.to_sql('merged_df2', new_conn, if_exists='replace', index=False)

# Reconnect to the newly created SQLite database
conn = sqlite3.connect('/Users/habeelabdi/Desktop/LL/LL 2/merged_df.db')

# Execute a SELECT query to fetch the data from the newly created table
query = 'SELECT * FROM merged_df2'  # Assuming 'merged_df2' is the table name
df_from_db = pd.read_sql_query(query, new_conn)

# Close the connection to the new database
new_conn.close()

# Print the DataFrame fetched from the database
print(df_from_db)
# Out:
#                        fsq_id  \
# 0    4b510060f964a520e93c27e3
# 1    60280caaaa745f79d2f50e15
# 2    4fd52f42e4b0b916eb02ab1b
# 3    4c1169396e5dc9b61b10b02d
# 4    4ba0153bf964a520995837e3
# ..                        ...
# 800                      None
# 801                      None
# 802                      None
# 803                      None
# 804                      None
#
#                                             categories  \
# 0    [{'id': 13035, 'name': 'Coffee Shop', 'short_n...
# 1    [{'id': 13034, 'name': 'Café', 'short_name': '...
# 2    [{'id': 13064, 'name': 'Pizzeria', 'short_name...
# 3    [{'id': 13031, 'name': 'Burger Joint', 'short_...
# 4    [{'id': 13064, 'name': 'Pizzeria', 'short_name...
# ..                                                 ...
# 800                                               None
# 801                                               None
# 802                                               None
# ...

# %%
import sqlite3
import pandas as pd

existing_conn = sqlite3.connect('/Users/habeelabdi/Desktop/LL/LL 2/merged_df.db')


existing_cursor = existing_conn.cursor()

existing_cursor.execute('SELECT rating, free_bikes, review_count, rating FROM merged_df2')

# Fetch all the rows from the result set
data = existing_cursor.fetchall()

# Close the cursor and connection to the existing database
existing_cursor.close()
existing_conn.close()

# Create a dataframe from the fetched data
df = pd.DataFrame(data, columns=[ 'distance', 'free_bikes', 'rating' , 'review_count'])

# Calculate correlation matrix
correlation_matrix = df.corr()

# Print the correlation matrix
print(correlation_matrix)
# Out:
#               distance  free_bikes    rating  review_count
# distance      1.000000         NaN  0.036698      1.000000
# free_bikes         NaN         1.0       NaN           NaN
# rating        0.036698         NaN  1.000000      0.036698
# review_count  1.000000         NaN  0.036698      1.000000
